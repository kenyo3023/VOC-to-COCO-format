# %%
import os
import json
import cv2
import numpy as np
import pandas as pd

# %%
root_path = '../VOC2012_coco/annotations'

# your annotations.json of data must in the 'food_100/annotations/' path
annot_path = os.path.join(root_path, 'annotations.json')

for path in [annot_path]:
    with open(path, 'r') as file:
        json_dict = json.load(open(path, 'r'))
    images = json_dict['images']
    annots = json_dict['annotations']
    print('images', len(images))
    print('annotations', len(annots))
# Out:
# images 5717
# annotations 15774

# %%
json_dict['annotations']
# Out:
# [{'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000008,
#   'bbox': [53, 87, 418, 333],
#   'category_id': 4,
#   'id': 0,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000008,
#   'bbox': [158, 44, 131, 123],
#   'category_id': 10,
#   'id': 1,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000015,
#   'bbox': [270, 1, 108, 175],
#   'category_id': 16,
#   'id': 2,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000015,
#   'bbox': [57, 1, 107, 149],
#   'category_id': 16,
#   'id': 3,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000019,
#   'bbox': [139, 2, 233, 195],
#   'category_id': 2,
#   'id': 4,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000019,
#   'bbox': [165, 66, 153, 170],
#   'category_id': 2,
#   'id': 5,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000019,
#   'bbox': [361, 1, 119, 111],
#   'category_id': 2,
#   'id': 6,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000023,
#   'bbox': [6, 1, 308, 261],
#   'category_id': 14,
#   'id': 7,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000023,
#   'bbox': [40, 97, 81, 314],
#   'category_id': 16,
#   'id': 8,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000023,
#   'bbox': [137, 36, 32, 73],
#   'category_id': 10,
#   'id': 9,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000023,
#   'bbox': [180, 36, 36, 68],
#   'category_id': 10,
#   'id': 10,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000023,
#   'bbox': [96, 39, 27, 64],
#   'category_id': 10,
#   'id': 11,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000028,
#   'bbox': [158, 199, 73, 41],
#   'category_id': 1,
#   'id': 12,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000028,
#   'bbox': [47, 202, 47, 36],
#   'category_id': 1,
#   'id': 13,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000033,
#   'bbox': [104, 61, 372, 196],
#   'category_id': 3,
#   'id': 14,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000036,
#   'bbox': [120, 1, 83, 34],
#   'category_id': 13,
#   'id': 15,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000036,
#   'bbox': [117, 38, 156, 83],
#   'category_id': 13,
#   'id': 16,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000036,
#   'bbox': [206, 74, 189, 163],
#   'category_id': 10,
#   'id': 17,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000036,
#   'bbox': [24, 2, 476, 186],
#   'category_id': 8,
#   'id': 18,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000036,
#   'bbox': [1, 187, 499, 95],
#   'category_id': 8,
#   'id': 19,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000037,
#   'bbox': [47, 157, 403, 125],
#   'category_id': 3,
#   'id': 20,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [271, 170, 115, 64],
#   'category_id': 10,
#   'id': 21,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [295, 189, 33, 42],
#   'category_id': 10,
#   'id': 22,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [206, 176, 50, 60],
#   'category_id': 10,
#   'id': 23,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [122, 162, 76, 168],
#   'category_id': 10,
#   'id': 24,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [457, 212, 43, 85],
#   'category_id': 10,
#   'id': 25,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [438, 173, 62, 70],
#   'category_id': 10,
#   'id': 26,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [351, 272, 101, 103],
#   'category_id': 6,
#   'id': 27,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [265, 250, 88, 114],
#   'category_id': 6,
#   'id': 28,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [189, 260, 97, 115],
#   'category_id': 6,
#   'id': 29,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [149, 224, 253, 107],
#   'category_id': 18,
#   'id': 30,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [54, 189, 30, 25],
#   'category_id': 19,
#   'id': 31,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000041,
#   'bbox': [358, 188, 111, 171],
#   'category_id': 10,
#   'id': 32,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000045,
#   'bbox': [45, 42, 410, 300],
#   'category_id': 12,
#   'id': 33,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000053,
#   'bbox': [54, 2, 446, 373],
#   'category_id': 2,
#   'id': 34,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000060,
#   'bbox': [1, 32, 342, 304],
#   'category_id': 5,
#   'id': 35,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000066,
#   'bbox': [1, 9, 438, 491],
#   'category_id': 2,
#   'id': 36,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000070,
#   'bbox': [180, 260, 33, 33],
#   'category_id': 14,
#   'id': 37,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000070,
#   'bbox': [367, 244, 80, 109],
#   'category_id': 6,
#   'id': 38,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000070,
#   'bbox': [255, 247, 116, 128],
#   'category_id': 6,
#   'id': 39,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000074,
#   'bbox': [46, 178, 341, 157],
#   'category_id': 1,
#   'id': 40,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000085,
#   'bbox': [1, 1, 394, 374],
#   'category_id': 1,
#   'id': 41,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000089,
#   'bbox': [71, 18, 236, 476],
#   'category_id': 6,
#   'id': 42,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000093,
#   'bbox': [392, 3, 87, 92],
#   'category_id': 14,
#   'id': 43,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000093,
#   'bbox': [307, 178, 105, 102],
#   'category_id': 6,
#   'id': 44,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000093,
#   'bbox': [328, 194, 145, 134],
#   'category_id': 6,
#   'id': 45,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000093,
#   'bbox': [143, 163, 177, 84],
#   'category_id': 9,
#   'id': 46,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000093,
#   'bbox': [1, 173, 144, 144],
#   'category_id': 9,
#   'id': 47,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000095,
#   'bbox': [251, 161, 36, 109],
#   'category_id': 0,
#   'id': 48,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000096,
#   'bbox': [1, 1, 499, 374],
#   'category_id': 10,
#   'id': 49,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000096,
#   'bbox': [96, 124, 320, 251],
#   'category_id': 5,
#   'id': 50,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000097,
#   'bbox': [101, 203, 80, 71],
#   'category_id': 0,
#   'id': 51,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000099,
#   'bbox': [122, 11, 214, 212],
#   'category_id': 2,
#   'id': 52,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000099,
#   'bbox': [98, 176, 327, 181],
#   'category_id': 7,
#   'id': 53,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000103,
#   'bbox': [156, 48, 131, 290],
#   'category_id': 0,
#   'id': 54,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000105,
#   'bbox': [215, 182, 162, 58],
#   'category_id': 1,
#   'id': 55,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000109,
#   'bbox': [293, 70, 127, 127],
#   'category_id': 15,
#   'id': 56,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000109,
#   'bbox': [41, 95, 403, 280],
#   'category_id': 1,
#   'id': 57,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000109,
#   'bbox': [228, 90, 110, 275],
#   'category_id': 10,
#   'id': 58,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000112,
#   'bbox': [83, 74, 303, 246],
#   'category_id': 5,
#   'id': 59,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000112,
#   'bbox': [324, 1, 70, 115],
#   'category_id': 16,
#   'id': 60,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000128,
#   'bbox': [11, 29, 489, 346],
#   'category_id': 9,
#   'id': 61,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000128,
#   'bbox': [1, 85, 360, 290],
#   'category_id': 10,
#   'id': 62,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000128,
#   'bbox': [92, 173, 120, 184],
#   'category_id': 10,
#   'id': 63,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000131,
#   'bbox': [185, 119, 147, 61],
#   'category_id': 0,
#   'id': 64,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000132,
#   'bbox': [431, 106, 43, 147],
#   'category_id': 10,
#   'id': 65,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000132,
#   'bbox': [39, 111, 42, 151],
#   'category_id': 10,
#   'id': 66,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000132,
#   'bbox': [1, 255, 499, 120],
#   'category_id': 11,
#   'id': 67,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000141,
#   'bbox': [94, 9, 406, 324],
#   'category_id': 4,
#   'id': 68,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000141,
#   'bbox': [42, 167, 33, 56],
#   'category_id': 10,
#   'id': 69,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000142,
#   'bbox': [109, 75, 385, 258],
#   'category_id': 4,
#   'id': 70,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000142,
#   'bbox': [93, 159, 12, 29],
#   'category_id': 10,
#   'id': 71,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000142,
#   'bbox': [36, 100, 93, 233],
#   'category_id': 10,
#   'id': 72,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000143,
#   'bbox': [370, 105, 47, 17],
#   'category_id': 1,
#   'id': 73,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000143,
#   'bbox': [392, 111, 108, 66],
#   'category_id': 1,
#   'id': 74,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000143,
#   'bbox': [1, 252, 499, 80],
#   'category_id': 1,
#   'id': 75,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000143,
#   'bbox': [129, 80, 107, 169],
#   'category_id': 15,
#   'id': 76,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000143,
#   'bbox': [102, 25, 110, 189],
#   'category_id': 10,
#   'id': 77,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000144,
#   'bbox': [147, 113, 212, 174],
#   'category_id': 15,
#   'id': 78,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000144,
#   'bbox': [185, 56, 102, 185],
#   'category_id': 10,
#   'id': 79,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000148,
#   'bbox': [1, 154, 56, 76],
#   'category_id': 8,
#   'id': 80,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000151,
#   'bbox': [244, 225, 31, 36],
#   'category_id': 3,
#   'id': 81,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000154,
#   'bbox': [39, 194, 72, 101],
#   'category_id': 16,
#   'id': 82,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000162,
#   'bbox': [47, 20, 447, 480],
#   'category_id': 2,
#   'id': 83,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000176,
#   'bbox': [5, 110, 495, 236],
#   'category_id': 1,
#   'id': 84,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000176,
#   'bbox': [200, 127, 102, 222],
#   'category_id': 10,
#   'id': 85,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000181,
#   'bbox': [46, 76, 377, 245],
#   'category_id': 5,
#   'id': 86,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000185,
#   'bbox': [256, 65, 46, 40],
#   'category_id': 10,
#   'id': 87,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000185,
#   'bbox': [159, 43, 306, 229],
#   'category_id': 1,
#   'id': 88,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000187,
#   'bbox': [160, 119, 283, 84],
#   'category_id': 1,
#   'id': 89,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000188,
#   'bbox': [45, 59, 350, 316],
#   'category_id': 19,
#   'id': 90,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000189,
#   'bbox': [254, 82, 52, 35],
#   'category_id': 10,
#   'id': 91,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000189,
#   'bbox': [53, 55, 336, 240],
#   'category_id': 1,
#   'id': 92,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000191,
#   'bbox': [200, 152, 133, 31],
#   'category_id': 8,
#   'id': 93,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000191,
#   'bbox': [68, 185, 26, 30],
#   'category_id': 10,
#   'id': 94,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000191,
#   'bbox': [23, 180, 32, 70],
#   'category_id': 10,
#   'id': 95,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000191,
#   'bbox': [57, 194, 94, 61],
#   'category_id': 13,
#   'id': 96,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000192,
#   'bbox': [249, 57, 192, 189],
#   'category_id': 0,
#   'id': 97,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000193,
#   'bbox': [103, 127, 220, 77],
#   'category_id': 1,
#   'id': 98,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000193,
#   'bbox': [230, 130, 24, 27],
#   'category_id': 10,
#   'id': 99,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000196,
#   'bbox': [348, 7, 152, 302],
#   'category_id': 13,
#   'id': 100,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000196,
#   'bbox': [340, 105, 160, 201],
#   'category_id': 19,
#   'id': 101,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000196,
#   'bbox': [432, 1, 33, 57],
#   'category_id': 16,
#   'id': 102,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000196,
#   'bbox': [481, 12, 19, 30],
#   'category_id': 16,
#   'id': 103,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000196,
#   'bbox': [1, 1, 205, 309],
#   'category_id': 13,
#   'id': 104,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000196,
#   'bbox': [193, 155, 85, 149],
#   'category_id': 5,
#   'id': 105,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000197,
#   'bbox': [95, 134, 135, 69],
#   'category_id': 3,
#   'id': 106,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000199,
#   'bbox': [412, 59, 88, 295],
#   'category_id': 10,
#   'id': 107,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000199,
#   'bbox': [229, 85, 157, 103],
#   'category_id': 1,
#   'id': 108,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000202,
#   'bbox': [60, 58, 65, 82],
#   'category_id': 10,
#   'id': 109,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000202,
#   'bbox': [145, 38, 107, 295],
#   'category_id': 10,
#   'id': 110,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000202,
#   'bbox': [245, 152, 97, 128],
#   'category_id': 10,
#   'id': 111,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000202,
#   'bbox': [337, 140, 124, 166],
#   'category_id': 10,
#   'id': 112,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000202,
#   'bbox': [17, 39, 142, 118],
#   'category_id': 14,
#   'id': 113,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000202,
#   'bbox': [430, 258, 24, 64],
#   'category_id': 16,
#   'id': 114,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000202,
#   'bbox': [14, 169, 80, 89],
#   'category_id': 6,
#   'id': 115,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000207,
#   'bbox': [72, 54, 181, 380],
#   'category_id': 10,
#   'id': 116,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000217,
#   'bbox': [64, 39, 195, 336],
#   'category_id': 10,
#   'id': 117,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000217,
#   'bbox': [238, 54, 185, 321],
#   'category_id': 10,
#   'id': 118,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000226,
#   'bbox': [386, 167, 21, 64],
#   'category_id': 10,
#   'id': 119,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000226,
#   'bbox': [310, 144, 25, 65],
#   'category_id': 10,
#   'id': 120,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000226,
#   'bbox': [284, 96, 22, 56],
#   'category_id': 10,
#   'id': 121,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000226,
#   'bbox': [311, 87, 23, 22],
#   'category_id': 10,
#   'id': 122,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000226,
#   'bbox': [152, 156, 151, 63],
#   'category_id': 1,
#   'id': 123,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000227,
#   'bbox': [120, 152, 304, 194],
#   'category_id': 5,
#   'id': 124,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000227,
#   'bbox': [194, 1, 190, 120],
#   'category_id': 6,
#   'id': 125,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000227,
#   'bbox': [1, 90, 467, 285],
#   'category_id': 18,
#   'id': 126,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000235,
#   'bbox': [286, 98, 85, 127],
#   'category_id': 10,
#   'id': 127,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000235,
#   'bbox': [111, 171, 377, 107],
#   'category_id': 8,
#   'id': 128,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000236,
#   'bbox': [62, 23, 320, 273],
#   'category_id': 10,
#   'id': 129,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000237,
#   'bbox': [75, 15, 18, 22],
#   'category_id': 19,
#   'id': 130,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000237,
#   'bbox': [1, 137, 31, 35],
#   'category_id': 15,
#   'id': 131,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000237,
#   'bbox': [180, 103, 139, 59],
#   'category_id': 1,
#   'id': 132,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000237,
#   'bbox': [252, 293, 36, 82],
#   'category_id': 10,
#   'id': 133,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000237,
#   'bbox': [209, 333, 36, 42],
#   'category_id': 10,
#   'id': 134,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000238,
#   'bbox': [1, 84, 478, 291],
#   'category_id': 11,
#   'id': 135,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000252,
#   'bbox': [184, 58, 155, 317],
#   'category_id': 10,
#   'id': 136,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000252,
#   'bbox': [443, 109, 28, 72],
#   'category_id': 10,
#   'id': 137,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000252,
#   'bbox': [165, 121, 39, 76],
#   'category_id': 10,
#   'id': 138,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000252,
#   'bbox': [1, 130, 46, 40],
#   'category_id': 1,
#   'id': 139,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000252,
#   'bbox': [194, 14, 306, 181],
#   'category_id': 11,
#   'id': 140,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000255,
#   'bbox': [81, 284, 19, 47],
#   'category_id': 10,
#   'id': 141,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000259,
#   'bbox': [161, 144, 77, 194],
#   'category_id': 10,
#   'id': 142,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000259,
#   'bbox': [234, 138, 59, 206],
#   'category_id': 10,
#   'id': 143,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000259,
#   'bbox': [369, 146, 55, 132],
#   'category_id': 10,
#   'id': 144,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000260,
#   'bbox': [191, 101, 51, 153],
#   'category_id': 10,
#   'id': 145,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000260,
#   'bbox': [303, 87, 197, 144],
#   'category_id': 1,
#   'id': 146,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000260,
#   'bbox': [1, 80, 146, 142],
#   'category_id': 1,
#   'id': 147,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000260,
#   'bbox': [65, 107, 118, 91],
#   'category_id': 1,
#   'id': 148,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000260,
#   'bbox': [223, 110, 36, 35],
#   'category_id': 1,
#   'id': 149,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000262,
#   'bbox': [23, 143, 407, 187],
#   'category_id': 8,
#   'id': 150,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000266,
#   'bbox': [16, 41, 149, 292],
#   'category_id': 10,
#   'id': 151,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000266,
#   'bbox': [77, 95, 84, 238],
#   'category_id': 10,
#   'id': 152,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000266,
#   'bbox': [144, 57, 122, 276],
#   'category_id': 10,
#   'id': 153,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000266,
#   'bbox': [220, 56, 72, 189],
#   'category_id': 10,
#   'id': 154,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000266,
#   'bbox': [250, 82, 97, 245],
#   'category_id': 10,
#   'id': 155,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000266,
#   'bbox': [262, 53, 191, 280],
#   'category_id': 10,
#   'id': 156,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000273,
#   'bbox': [184, 50, 259, 235],
#   'category_id': 2,
#   'id': 157,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000273,
#   'bbox': [1, 158, 239, 161],
#   'category_id': 2,
#   'id': 158,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000273,
#   'bbox': [1, 1, 463, 109],
#   'category_id': 6,
#   'id': 159,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000273,
#   'bbox': [1, 1, 222, 160],
#   'category_id': 6,
#   'id': 160,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000275,
#   'bbox': [167, 187, 25, 87],
#   'category_id': 10,
#   'id': 161,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000275,
#   'bbox': [184, 190, 18, 82],
#   'category_id': 10,
#   'id': 162,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000275,
#   'bbox': [197, 187, 34, 93],
#   'category_id': 10,
#   'id': 163,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000275,
#   'bbox': [224, 187, 22, 41],
#   'category_id': 10,
#   'id': 164,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000275,
#   'bbox': [250, 203, 22, 68],
#   'category_id': 10,
#   'id': 165,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000275,
#   'bbox': [322, 199, 20, 70],
#   'category_id': 10,
#   'id': 166,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000275,
#   'bbox': [474, 15, 26, 26],
#   'category_id': 19,
#   'id': 167,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000275,
#   'bbox': [441, 16, 31, 21],
#   'category_id': 19,
#   'id': 168,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000283,
#   'bbox': [32, 95, 138, 238],
#   'category_id': 10,
#   'id': 169,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000283,
#   'bbox': [387, 126, 49, 101],
#   'category_id': 10,
#   'id': 170,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000284,
#   'bbox': [121, 20, 298, 355],
#   'category_id': 10,
#   'id': 171,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000284,
#   'bbox': [10, 1, 118, 322],
#   'category_id': 19,
#   'id': 172,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000287,
#   'bbox': [285, 100, 141, 221],
#   'category_id': 19,
#   'id': 173,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000287,
#   'bbox': [3, 27, 223, 276],
#   'category_id': 19,
#   'id': 174,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000289,
#   'bbox': [47, 149, 138, 351],
#   'category_id': 10,
#   'id': 175,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000290,
#   'bbox': [65, 49, 325, 309],
#   'category_id': 10,
#   'id': 176,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000290,
#   'bbox': [389, 156, 92, 215],
#   'category_id': 16,
#   'id': 177,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000290,
#   'bbox': [7, 297, 493, 74],
#   'category_id': 18,
#   'id': 178,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000291,
#   'bbox': [2, 196, 215, 55],
#   'category_id': 3,
#   'id': 179,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000291,
#   'bbox': [392, 198, 47, 22],
#   'category_id': 3,
#   'id': 180,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000297,
#   'bbox': [2, 87, 300, 209],
#   'category_id': 10,
#   'id': 181,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000297,
#   'bbox': [87, 205, 143, 126],
#   'category_id': 6,
#   'id': 182,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000297,
#   'bbox': [260, 188, 112, 143],
#   'category_id': 6,
#   'id': 183,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000297,
#   'bbox': [5, 141, 116, 152],
#   'category_id': 6,
#   'id': 184,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000297,
#   'bbox': [225, 113, 130, 222],
#   'category_id': 10,
#   'id': 185,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000309,
#   'bbox': [1, 40, 97, 182],
#   'category_id': 14,
#   'id': 186,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000309,
#   'bbox': [240, 159, 173, 170],
#   'category_id': 14,
#   'id': 187,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000311,
#   'bbox': [240, 66, 200, 240],
#   'category_id': 10,
#   'id': 188,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000311,
#   'bbox': [21, 74, 223, 235],
#   'category_id': 10,
#   'id': 189,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000311,
#   'bbox': [57, 302, 443, 31],
#   'category_id': 18,
#   'id': 190,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000311,
#   'bbox': [70, 141, 35, 32],
#   'category_id': 10,
#   'id': 191,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000311,
#   'bbox': [215, 117, 61, 77],
#   'category_id': 10,
#   'id': 192,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000313,
#   'bbox': [73, 45, 259, 330],
#   'category_id': 10,
#   'id': 193,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000315,
#   'bbox': [208, 209, 55, 26],
#   'category_id': 1,
#   'id': 194,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000315,
#   'bbox': [347, 200, 37, 20],
#   'category_id': 1,
#   'id': 195,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000315,
#   'bbox': [379, 178, 60, 39],
#   'category_id': 11,
#   'id': 196,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000315,
#   'bbox': [132, 208, 9, 26],
#   'category_id': 10,
#   'id': 197,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000315,
#   'bbox': [138, 216, 9, 17],
#   'category_id': 10,
#   'id': 198,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000315,
#   'bbox': [285, 199, 21, 13],
#   'category_id': 15,
#   'id': 199,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000316,
#   'bbox': [75, 95, 321, 280],
#   'category_id': 10,
#   'id': 200,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000318,
#   'bbox': [1, 79, 381, 421],
#   'category_id': 0,
#   'id': 201,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000330,
#   'bbox': [88, 59, 412, 316],
#   'category_id': 2,
#   'id': 202,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000330,
#   'bbox': [165, 1, 335, 374],
#   'category_id': 10,
#   'id': 203,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000335,
#   'bbox': [93, 89, 267, 171],
#   'category_id': 17,
#   'id': 204,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000335,
#   'bbox': [1, 93, 109, 131],
#   'category_id': 17,
#   'id': 205,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000335,
#   'bbox': [441, 173, 48, 18],
#   'category_id': 17,
#   'id': 206,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000335,
#   'bbox': [360, 175, 31, 14],
#   'category_id': 17,
#   'id': 207,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000336,
#   'bbox': [115, 119, 202, 197],
#   'category_id': 2,
#   'id': 208,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000338,
#   'bbox': [338, 72, 162, 303],
#   'category_id': 10,
#   'id': 209,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000338,
#   'bbox': [12, 56, 173, 319],
#   'category_id': 10,
#   'id': 210,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000338,
#   'bbox': [130, 236, 212, 139],
#   'category_id': 18,
#   'id': 211,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000342,
#   'bbox': [114, 258, 33, 98],
#   'category_id': 10,
#   'id': 212,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000343,
#   'bbox': [359, 162, 51, 139],
#   'category_id': 10,
#   'id': 213,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000343,
#   'bbox': [1, 1, 331, 337],
#   'category_id': 12,
#   'id': 214,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000343,
#   'bbox': [422, 180, 16, 43],
#   'category_id': 10,
#   'id': 215,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000346,
#   'bbox': [123, 67, 93, 242],
#   'category_id': 10,
#   'id': 216,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000346,
#   'bbox': [186, 130, 276, 200],
#   'category_id': 1,
#   'id': 217,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000346,
#   'bbox': [1, 98, 132, 192],
#   'category_id': 1,
#   'id': 218,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000348,
#   'bbox': [185, 157, 94, 108],
#   'category_id': 14,
#   'id': 219,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000348,
#   'bbox': [274, 82, 90, 118],
#   'category_id': 14,
#   'id': 220,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000350,
#   'bbox': [155, 42, 324, 363],
#   'category_id': 0,
#   'id': 221,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000350,
#   'bbox': [14, 170, 167, 330],
#   'category_id': 0,
#   'id': 222,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000356,
#   'bbox': [141, 195, 70, 46],
#   'category_id': 1,
#   'id': 223,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000361,
#   'bbox': [67, 62, 338, 272],
#   'category_id': 0,
#   'id': 224,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000364,
#   'bbox': [99, 123, 176, 252],
#   'category_id': 10,
#   'id': 225,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000364,
#   'bbox': [219, 139, 185, 231],
#   'category_id': 10,
#   'id': 226,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000365,
#   'bbox': [168, 129, 95, 96],
#   'category_id': 10,
#   'id': 227,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000371,
#   'bbox': [189, 129, 185, 147],
#   'category_id': 4,
#   'id': 228,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000371,
#   'bbox': [191, 146, 25, 33],
#   'category_id': 4,
#   'id': 229,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000371,
#   'bbox': [259, 95, 46, 113],
#   'category_id': 10,
#   'id': 230,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000380,
#   'bbox': [337, 208, 163, 167],
#   'category_id': 10,
#   'id': 231,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000380,
#   'bbox': [140, 249, 185, 126],
#   'category_id': 10,
#   'id': 232,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000380,
#   'bbox': [26, 269, 128, 106],
#   'category_id': 10,
#   'id': 233,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000392,
#   'bbox': [115, 161, 111, 339],
#   'category_id': 10,
#   'id': 234,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000392,
#   'bbox': [315, 178, 60, 322],
#   'category_id': 10,
#   'id': 235,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000392,
#   'bbox': [282, 179, 52, 209],
#   'category_id': 10,
#   'id': 236,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [69, 94, 68, 219],
#   'category_id': 10,
#   'id': 237,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [144, 106, 64, 209],
#   'category_id': 10,
#   'id': 238,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [221, 122, 61, 195],
#   'category_id': 10,
#   'id': 239,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [17, 110, 50, 133],
#   'category_id': 10,
#   'id': 240,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [426, 167, 34, 62],
#   'category_id': 10,
#   'id': 241,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [430, 218, 60, 102],
#   'category_id': 10,
#   'id': 242,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [384, 162, 45, 63],
#   'category_id': 10,
#   'id': 243,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [208, 116, 33, 57],
#   'category_id': 10,
#   'id': 244,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [267, 131, 30, 64],
#   'category_id': 10,
#   'id': 245,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [347, 150, 36, 90],
#   'category_id': 10,
#   'id': 246,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [196, 178, 159, 129],
#   'category_id': 15,
#   'id': 247,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [274, 163, 106, 130],
#   'category_id': 15,
#   'id': 248,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [108, 91, 41, 76],
#   'category_id': 10,
#   'id': 249,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [1, 112, 24, 44],
#   'category_id': 10,
#   'id': 250,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [429, 228, 10, 18],
#   'category_id': 16,
#   'id': 251,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [423, 226, 8, 22],
#   'category_id': 16,
#   'id': 252,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [418, 230, 9, 20],
#   'category_id': 16,
#   'id': 253,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000393,
#   'bbox': [410, 229, 9, 32],
#   'category_id': 16,
#   'id': 254,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000397,
#   'bbox': [1, 333, 188, 167],
#   'category_id': 6,
#   'id': 255,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000397,
#   'bbox': [17, 284, 358, 216],
#   'category_id': 18,
#   'id': 256,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000397,
#   'bbox': [61, 269, 155, 200],
#   'category_id': 6,
#   'id': 257,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000397,
#   'bbox': [150, 259, 117, 184],
#   'category_id': 6,
#   'id': 258,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000397,
#   'bbox': [321, 257, 54, 162],
#   'category_id': 6,
#   'id': 259,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000399,
#   'bbox': [25, 87, 353, 114],
#   'category_id': 1,
#   'id': 260,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000400,
#   'bbox': [216, 157, 81, 77],
#   'category_id': 0,
#   'id': 261,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000405,
#   'bbox': [383, 102, 117, 37],
#   'category_id': 8,
#   'id': 262,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000405,
#   'bbox': [88, 101, 295, 37],
#   'category_id': 8,
#   'id': 263,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000405,
#   'bbox': [1, 97, 86, 41],
#   'category_id': 8,
#   'id': 264,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000415,
#   'bbox': [1, 132, 254, 243],
#   'category_id': 10,
#   'id': 265,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000416,
#   'bbox': [69, 169, 210, 330],
#   'category_id': 10,
#   'id': 266,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000416,
#   'bbox': [303, 169, 72, 331],
#   'category_id': 10,
#   'id': 267,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000421,
#   'bbox': [1, 171, 307, 204],
#   'category_id': 10,
#   'id': 268,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000421,
#   'bbox': [61, 161, 353, 214],
#   'category_id': 10,
#   'id': 269,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000421,
#   'bbox': [409, 128, 17, 30],
#   'category_id': 16,
#   'id': 270,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000421,
#   'bbox': [1, 141, 445, 234],
#   'category_id': 9,
#   'id': 271,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000421,
#   'bbox': [156, 106, 332, 269],
#   'category_id': 10,
#   'id': 272,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000422,
#   'bbox': [25, 36, 275, 371],
#   'category_id': 10,
#   'id': 273,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000426,
#   'bbox': [25, 1, 475, 331],
#   'category_id': 10,
#   'id': 274,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000428,
#   'bbox': [1, 43, 377, 194],
#   'category_id': 4,
#   'id': 275,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000432,
#   'bbox': [215, 2, 231, 373],
#   'category_id': 10,
#   'id': 276,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000432,
#   'bbox': [36, 1, 106, 199],
#   'category_id': 6,
#   'id': 277,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000435,
#   'bbox': [1, 237, 446, 98],
#   'category_id': 18,
#   'id': 278,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000435,
#   'bbox': [78, 36, 140, 204],
#   'category_id': 10,
#   'id': 279,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000435,
#   'bbox': [200, 12, 189, 231],
#   'category_id': 10,
#   'id': 280,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000435,
#   'bbox': [164, 174, 91, 72],
#   'category_id': 10,
#   'id': 281,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000436,
#   'bbox': [97, 66, 204, 269],
#   'category_id': 10,
#   'id': 282,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000437,
#   'bbox': [65, 342, 86, 33],
#   'category_id': 8,
#   'id': 283,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000437,
#   'bbox': [99, 337, 73, 27],
#   'category_id': 8,
#   'id': 284,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000442,
#   'bbox': [10, 24, 322, 390],
#   'category_id': 10,
#   'id': 285,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000442,
#   'bbox': [1, 1, 314, 446],
#   'category_id': 10,
#   'id': 286,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000443,
#   'bbox': [35, 1, 274, 408],
#   'category_id': 10,
#   'id': 287,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000445,
#   'bbox': [44, 139, 222, 266],
#   'category_id': 10,
#   'id': 288,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000447,
#   'bbox': [84, 156, 176, 253],
#   'category_id': 10,
#   'id': 289,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000447,
#   'bbox': [59, 27, 248, 420],
#   'category_id': 10,
#   'id': 290,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000448,
#   'bbox': [1, 16, 277, 484],
#   'category_id': 10,
#   'id': 291,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000448,
#   'bbox': [81, 255, 266, 245],
#   'category_id': 10,
#   'id': 292,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000455,
#   'bbox': [1, 1, 499, 332],
#   'category_id': 10,
#   'id': 293,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000461,
#   'bbox': [3, 8, 497, 367],
#   'category_id': 10,
#   'id': 294,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000461,
#   'bbox': [7, 82, 130, 198],
#   'category_id': 10,
#   'id': 295,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008000461,
#   'bbox': [3, 109, 46, 113],
#   'category_id': 10,
#   'id': 296,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
# ...
#   'iscrowd': 0,
#   'image_id': 2008001413,
#   'bbox': [65, 41, 269, 334],
#   'category_id': 10,
#   'id': 901,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001414,
#   'bbox': [57, 31, 425, 370],
#   'category_id': 5,
#   'id': 902,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001419,
#   'bbox': [8, 168, 139, 168],
#   'category_id': 10,
#   'id': 903,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001419,
#   'bbox': [106, 198, 149, 137],
#   'category_id': 10,
#   'id': 904,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001419,
#   'bbox': [225, 205, 92, 131],
#   'category_id': 10,
#   'id': 905,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001419,
#   'bbox': [310, 202, 138, 134],
#   'category_id': 10,
#   'id': 906,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001420,
#   'bbox': [343, 148, 50, 104],
#   'category_id': 2,
#   'id': 907,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001420,
#   'bbox': [118, 210, 61, 152],
#   'category_id': 2,
#   'id': 908,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001420,
#   'bbox': [79, 129, 97, 55],
#   'category_id': 2,
#   'id': 909,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001420,
#   'bbox': [38, 169, 64, 111],
#   'category_id': 2,
#   'id': 910,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001420,
#   'bbox': [265, 26, 53, 153],
#   'category_id': 10,
#   'id': 911,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001420,
#   'bbox': [336, 1, 116, 48],
#   'category_id': 8,
#   'id': 912,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001431,
#   'bbox': [26, 88, 347, 412],
#   'category_id': 10,
#   'id': 913,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001431,
#   'bbox': [102, 249, 58, 180],
#   'category_id': 16,
#   'id': 914,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001431,
#   'bbox': [265, 227, 59, 176],
#   'category_id': 16,
#   'id': 915,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001434,
#   'bbox': [173, 169, 177, 201],
#   'category_id': 10,
#   'id': 916,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001434,
#   'bbox': [238, 160, 59, 94],
#   'category_id': 10,
#   'id': 917,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001434,
#   'bbox': [211, 271, 135, 104],
#   'category_id': 6,
#   'id': 918,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001434,
#   'bbox': [1, 262, 72, 103],
#   'category_id': 6,
#   'id': 919,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001434,
#   'bbox': [79, 197, 70, 32],
#   'category_id': 6,
#   'id': 920,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001434,
#   'bbox': [330, 194, 104, 112],
#   'category_id': 6,
#   'id': 921,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001434,
#   'bbox': [428, 152, 72, 223],
#   'category_id': 19,
#   'id': 922,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001434,
#   'bbox': [52, 215, 232, 160],
#   'category_id': 18,
#   'id': 923,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001440,
#   'bbox': [205, 79, 63, 37],
#   'category_id': 1,
#   'id': 924,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001440,
#   'bbox': [14, 67, 118, 72],
#   'category_id': 1,
#   'id': 925,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001440,
#   'bbox': [1, 135, 108, 343],
#   'category_id': 1,
#   'id': 926,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001440,
#   'bbox': [1, 106, 44, 30],
#   'category_id': 1,
#   'id': 927,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001440,
#   'bbox': [59, 97, 250, 403],
#   'category_id': 10,
#   'id': 928,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001440,
#   'bbox': [5, 51, 302, 449],
#   'category_id': 10,
#   'id': 929,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001444,
#   'bbox': [291, 198, 51, 171],
#   'category_id': 16,
#   'id': 930,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001444,
#   'bbox': [9, 2, 491, 373],
#   'category_id': 10,
#   'id': 931,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001446,
#   'bbox': [69, 22, 378, 316],
#   'category_id': 1,
#   'id': 932,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001446,
#   'bbox': [176, 14, 73, 27],
#   'category_id': 1,
#   'id': 933,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001448,
#   'bbox': [332, 126, 137, 43],
#   'category_id': 3,
#   'id': 934,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001448,
#   'bbox': [1, 89, 297, 80],
#   'category_id': 3,
#   'id': 935,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001454,
#   'bbox': [5, 1, 485, 499],
#   'category_id': 10,
#   'id': 936,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001455,
#   'bbox': [155, 13, 178, 400],
#   'category_id': 10,
#   'id': 937,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001455,
#   'bbox': [3, 2, 206, 402],
#   'category_id': 10,
#   'id': 938,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001460,
#   'bbox': [112, 1, 381, 366],
#   'category_id': 19,
#   'id': 939,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001461,
#   'bbox': [439, 94, 61, 134],
#   'category_id': 6,
#   'id': 940,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001461,
#   'bbox': [433, 74, 65, 50],
#   'category_id': 14,
#   'id': 941,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001461,
#   'bbox': [1, 91, 188, 197],
#   'category_id': 9,
#   'id': 942,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001461,
#   'bbox': [107, 30, 133, 224],
#   'category_id': 10,
#   'id': 943,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001461,
#   'bbox': [196, 178, 80, 131],
#   'category_id': 2,
#   'id': 944,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001462,
#   'bbox': [80, 67, 128, 226],
#   'category_id': 10,
#   'id': 945,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001464,
#   'bbox': [153, 192, 180, 198],
#   'category_id': 4,
#   'id': 946,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001464,
#   'bbox': [215, 176, 60, 122],
#   'category_id': 10,
#   'id': 947,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001464,
#   'bbox': [23, 268, 30, 80],
#   'category_id': 10,
#   'id': 948,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001464,
#   'bbox': [84, 278, 22, 81],
#   'category_id': 10,
#   'id': 949,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001464,
#   'bbox': [92, 282, 30, 84],
#   'category_id': 10,
#   'id': 950,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001464,
#   'bbox': [119, 276, 32, 92],
#   'category_id': 10,
#   'id': 951,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001464,
#   'bbox': [291, 251, 21, 27],
#   'category_id': 10,
#   'id': 952,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001464,
#   'bbox': [318, 251, 15, 34],
#   'category_id': 10,
#   'id': 953,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001464,
#   'bbox': [320, 275, 13, 90],
#   'category_id': 10,
#   'id': 954,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001467,
#   'bbox': [36, 36, 108, 217],
#   'category_id': 10,
#   'id': 955,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001467,
#   'bbox': [335, 1, 68, 139],
#   'category_id': 19,
#   'id': 956,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001467,
#   'bbox': [55, 107, 96, 152],
#   'category_id': 6,
#   'id': 957,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001467,
#   'bbox': [229, 80, 102, 61],
#   'category_id': 19,
#   'id': 958,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001479,
#   'bbox': [88, 63, 337, 306],
#   'category_id': 2,
#   'id': 959,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001482,
#   'bbox': [168, 61, 132, 439],
#   'category_id': 10,
#   'id': 960,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001482,
#   'bbox': [75, 62, 114, 438],
#   'category_id': 10,
#   'id': 961,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001482,
#   'bbox': [209, 287, 30, 58],
#   'category_id': 16,
#   'id': 962,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001488,
#   'bbox': [156, 1, 344, 332],
#   'category_id': 10,
#   'id': 963,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001493,
#   'bbox': [131, 21, 131, 348],
#   'category_id': 10,
#   'id': 964,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001493,
#   'bbox': [245, 80, 96, 288],
#   'category_id': 10,
#   'id': 965,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001493,
#   'bbox': [318, 53, 105, 322],
#   'category_id': 10,
#   'id': 966,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001493,
#   'bbox': [6, 66, 151, 309],
#   'category_id': 10,
#   'id': 967,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001493,
#   'bbox': [442, 64, 39, 133],
#   'category_id': 10,
#   'id': 968,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001493,
#   'bbox': [434, 199, 66, 176],
#   'category_id': 6,
#   'id': 969,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001493,
#   'bbox': [401, 72, 20, 36],
#   'category_id': 10,
#   'id': 970,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001493,
#   'bbox': [406, 68, 34, 124],
#   'category_id': 10,
#   'id': 971,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001495,
#   'bbox': [7, 8, 488, 229],
#   'category_id': 0,
#   'id': 972,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001498,
#   'bbox': [152, 103, 220, 115],
#   'category_id': 2,
#   'id': 973,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001500,
#   'bbox': [223, 288, 44, 34],
#   'category_id': 1,
#   'id': 974,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001500,
#   'bbox': [197, 312, 50, 37],
#   'category_id': 1,
#   'id': 975,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001500,
#   'bbox': [251, 268, 31, 23],
#   'category_id': 1,
#   'id': 976,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [20, 135, 63, 133],
#   'category_id': 10,
#   'id': 977,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [93, 152, 39, 111],
#   'category_id': 10,
#   'id': 978,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [146, 132, 41, 129],
#   'category_id': 10,
#   'id': 979,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [186, 134, 66, 139],
#   'category_id': 10,
#   'id': 980,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [237, 146, 75, 128],
#   'category_id': 10,
#   'id': 981,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [285, 164, 89, 113],
#   'category_id': 10,
#   'id': 982,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [175, 180, 24, 57],
#   'category_id': 10,
#   'id': 983,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [402, 199, 28, 89],
#   'category_id': 10,
#   'id': 984,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [422, 196, 24, 87],
#   'category_id': 10,
#   'id': 985,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [1, 163, 14, 33],
#   'category_id': 10,
#   'id': 986,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001501,
#   'bbox': [337, 183, 19, 53],
#   'category_id': 10,
#   'id': 987,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001510,
#   'bbox': [61, 106, 318, 271],
#   'category_id': 10,
#   'id': 988,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001523,
#   'bbox': [115, 244, 99, 105],
#   'category_id': 13,
#   'id': 989,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001523,
#   'bbox': [118, 160, 80, 148],
#   'category_id': 10,
#   'id': 990,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001525,
#   'bbox': [184, 176, 77, 159],
#   'category_id': 10,
#   'id': 991,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001525,
#   'bbox': [162, 218, 108, 157],
#   'category_id': 15,
#   'id': 992,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001525,
#   'bbox': [269, 238, 231, 137],
#   'category_id': 15,
#   'id': 993,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001525,
#   'bbox': [355, 233, 145, 142],
#   'category_id': 15,
#   'id': 994,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001525,
#   'bbox': [228, 171, 36, 149],
#   'category_id': 10,
#   'id': 995,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001529,
#   'bbox': [58, 1, 442, 247],
#   'category_id': 8,
#   'id': 996,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001529,
#   'bbox': [168, 209, 17, 33],
#   'category_id': 10,
#   'id': 997,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001529,
#   'bbox': [216, 208, 17, 22],
#   'category_id': 10,
#   'id': 998,
#   'ignore': 0},
#  {'segmentation': None,
#   'area': None,
#   'iscrowd': 0,
#   'image_id': 2008001533,
#   'bbox': [141, 106, 66, 216],
#   'category_id': 10,
#   'id': 999,
#   'ignore': 0},
#  ...]

# %%
for annot in json_dict['annotations']:
    annot['iscrowd'] = 0
    annot['ignore'] = 0
    annot['area'] = annot['bbox'][2] * annot['bbox'][3]

# %%
data_index = sorted([meta['id'] for meta in json_dict['images']])
size = len(data_index)
train_size = int(size * 0.7)
test_size = int(size * 0.15)
val_size = int(size * 0.15)

np.random.seed(0)

train_index = np.random.choice(data_index, train_size, replace=False)

test_index = np.setdiff1d(data_index, train_index)

val_index = np.random.choice(test_index, val_size, replace=False)

test_index = np.setdiff1d(test_index, val_index)

# %%
print('total number images')
print('data: ', len(data_index))
print('train', len(train_index))
print('test', len(test_index))
print('val', len(val_index))
# Out:
# total number images
# data:  5717
# train 4001
# test 859
# val 857

# %%
train = {"info": json_dict['info'],
             "licenses": json_dict['licenses'],
             "images": [meta for meta in json_dict['images'] if meta['id'] in train_index],
             "annotations": [meta for meta in json_dict['annotations'] if meta['image_id'] in train_index],
             "categories":json_dict['categories']}
test = {"info": json_dict['info'],
             "licenses": json_dict['licenses'],
             "images": [meta for meta in json_dict['images'] if meta['id'] in test_index],
             "annotations": [meta for meta in json_dict['annotations'] if meta['image_id'] in test_index],
             "categories":json_dict['categories']}
val = {"info": json_dict['info'],
             "licenses": json_dict['licenses'],
             "images": [meta for meta in json_dict['images'] if meta['id'] in val_index],
             "annotations": [meta for meta in json_dict['annotations'] if meta['image_id'] in val_index],
             "categories":json_dict['categories']}

# %%
class_count = pd.DataFrame()
class_count['train_count'] = pd.DataFrame([instance['category_id'] for instance in train['annotations']]).value_counts().sort_index()
class_count['val_count'] = pd.DataFrame([instance['category_id'] for instance in val['annotations']]).value_counts().sort_index()
class_count['test_count'] = pd.DataFrame([instance['category_id'] for instance in test['annotations']]).value_counts().sort_index()
class_count = class_count.reset_index(drop=True)
class_count.index = [i for i in range(1,21)]
class_count
# Out:
#     train_count  val_count  test_count
# 1           361        107         124
# 2           872        155         164
# 3           520        112         136
# 4           324         74          72
# 5           272         62          43
# 6           438         95          76
# 7          1057        202         198
# 8           298        110         101
# 9           364         83          61
# 10          266         69          64
# 11         3647        649         723
# 12          224         44          49
# 13          224         50          53
# 14          300         53          57
# 15          283         62          67
# 16          257         72          46
# 17          560        105          84
# 18          263         41          51
# 19          260         60          53
# 20          408         77          72

# %%
print('total number annotations')
print('data', len(json_dict['annotations']))
print('train', len(train['annotations']))
print('test', len(test['annotations']))
print('val', len(val['annotations']))
# Out:
# total number annotations
# data 15774
# train 11198
# test 2294
# val 2282

# %%
# for name, meta in zip(['train_voc.json', 'test_voc.json', 'val_voc.json'], 
#                       [train, test, val]):
#     with open(os.path.join(root_path, name), 'w') as outfile:
#          json.dump(meta, outfile)

# %%
# your annotations.json of data must in the 'food_100/annotations/' path
annot_path = os.path.join(root_path, 'val_voc.json')

for path in [annot_path]:
    with open(path, 'r') as file:
        json_dict = json.load(open(path, 'r'))
    images = json_dict['images']
    annots = json_dict['annotations']
    print('images', len(images))
    print('annotations', len(annots))
# Out:
# images 857
# annotations 2282

# %%
class_name = ['__background__']
for dct in json_dict['categories']:
    class_name.append('%d %s'%(dct['id'], dct['name']))

# %%
class_name
# Out:
# ['__background__',
#  '0 bird',
#  '1 car',
#  '2 dog',
#  '3 aeroplane',
#  '4 horse',
#  '5 cat',
#  '6 chair',
#  '7 sheep',
#  '8 boat',
#  '9 sofa',
#  '10 person',
#  '11 bus',
#  '12 train',
#  '13 bicycle',
#  '14 tvmonitor',
#  '15 motorbike',
#  '16 bottle',
#  '17 cow',
#  '18 diningtable',
#  '19 pottedplant']
